# %%
import pandas as pd
import numpy as np
import seacrowd as sc
import pandasai as pai
from datasets import load_dataset

# %%
nq_open = load_dataset("google-research-datasets/nq_open", trust_remote_code=True)
filwordnet = load_dataset("SEACrowd/filwordnet", trust_remote_code=True)
trivia_qa = load_dataset("mandarjoshi/trivia_qa", "rc", trust_remote_code=True)
wiki_qa = load_dataset("microsoft/wiki_qa", trust_remote_code=True)
# Out:
# ...
# Loading dataset shards:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
print(nq_open.keys())
print(filwordnet.keys())
print(trivia_qa.keys())
print(wiki_qa.keys())
# Out:
# dict_keys(['train', 'validation'])
# dict_keys(['train'])
# dict_keys(['train', 'validation', 'test'])
# dict_keys(['test', 'validation', 'train'])

# %%
pd.DataFrame(nq_open["train"][:5])
# Out:
#                                             question  \
# 0           where did they film hot tub time machine
# 1   who has the right of way in international waters
# 2            who does annie work for attack on titan
# 3  when was the immigration reform and control ac...
# 4              when was puerto rico added to the usa
# 5  who has been chosen for best supporting actres...
# 6         which side of the white house is the front
# 7  names of the metropolitan municipalities in so...
# 8               who's hosting the super bowl in 2019
# 9  in which year vivo launch its first phone in i...
#
#                                               answer
# 0                             [Fernie Alpine Resort]
# 1                                   [Neither vessel]
# 2                                           [Marley]
# 3                                 [November 6, 1986]
# 4                                             [1950]
# 5                                      [Zaira Wasim]
# ...

# %%
pd.DataFrame(filwordnet["train"][:5])
# Out:
#    word_id       lemma  synset_id  sense_id pos  lexdomain_id  \
# 0    51421      matino  302262136     50225   a             0
# 1    49082      maayos  302262136     50226   a             0
# 2    51420  hanapbuhay  100553013     50224   n             0
# 3    51419     trabaho  100553013     50223   n             0
# 4    51419     trabaho  100584367     52818   n             0
# 5    53524        obra  100584367     52817   n             0
# 6    53525      gawain  100584367     52819   n             0
# 7    51418     matibay  301086211     50361   a             0
# 8    51521     makunat  301086211     50360   a             0
# 9    51418     matibay  301973490     50222   a             0
#
#                                 definition  last_modifier      sumo
# 0                     nasa tamang pagiisip              1      None
# 1                     nasa tamang pagiisip              1      None
# 2                      paraan ng pamumuhay              1      None
# ...

# %%
pd.DataFrame(trivia_qa["train"][:5])
# Out:
#                                             question question_id  \
# 0  Which American-born Sinclair won the Nobel Pri...        tc_1
# 1         Where in England was Dame Judi Dench born?        tc_3
# 2  In which decade did Billboard magazine first p...        tc_5
# 3  From which country did Angola achieve independ...        tc_8
# 4              Which city does David Soul come from?        tc_9
#
#                  question_source  \
# 0  http://www.triviacountry.com/
# 1  http://www.triviacountry.com/
# 2  http://www.triviacountry.com/
# 3  http://www.triviacountry.com/
# 4  http://www.triviacountry.com/
#
#                                         entity_pages  \
# 0  {'doc_source': [], 'filename': [], 'title': []...
# 1  {'doc_source': ['TagMe', 'TagMe'], 'filename':...
# 2  {'doc_source': [], 'filename': [], 'title': []...
# 3  {'doc_source': ['TagMe', 'TagMe', 'Search'], '...
# 4  {'doc_source': ['TagMe'], 'filename': ['David_...
#
# ...

# %%
pd.DataFrame(wiki_qa["train"][:5])
# Out:
#   question_id                       question document_title  \
# 0          Q1  how are glacier caves formed?   Glacier cave
# 1          Q1  how are glacier caves formed?   Glacier cave
# 2          Q1  how are glacier caves formed?   Glacier cave
# 3          Q1  how are glacier caves formed?   Glacier cave
# 4          Q1  how are glacier caves formed?   Glacier cave
#
#                                               answer  label
# 0  A partly submerged glacier cave on Perito More...      0
# 1          The ice facade is approximately 60 m high      0
# 2          Ice formations in the Titlis glacier cave      0
# 3  A glacier cave is a cave formed within the ice...      1
# 4  Glacier caves are often called ice caves , but...      0
