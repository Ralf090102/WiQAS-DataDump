# %%
import pandas as pd
import numpy as np

# %%
import json
import os

# Define 100 question-answer pairs
eval_data = [
    {"item": 1, "question": "Who is the national hero of the Philippines?", "answer": "Jose Rizal"},
    {"item": 2, "question": "Ano ang ibig sabihin ng ‘bayanihan’ sa kulturang Pilipino?", "answer": "Ang bayanihan ay ang tradisyon ng pagtutulungan at pagkakaisa sa komunidad, tulad ng sama-samang paglilipat ng bahay-kubo."},
    {"item": 3, "question": "What is the most famous Filipino dish?", "answer": "Adobo is often considered the most famous Filipino dish, known for its savory blend of soy sauce, vinegar, and spices."},
    {"item": 4, "question": "Ano ang pangalan ng tradisyunal na sayaw na ginagawa sa mga pista sa Cebu?", "answer": "Ang Sinulog ay ang tradisyunal na sayaw na ginagawa sa pista ng Sto. Niño sa Cebu."},
    {"item": 5, "question": "What is the significance of the Barong Tagalog in Filipino culture?", "answer": "The Barong Tagalog is a traditional Filipino garment worn for formal occasions, symbolizing elegance and national pride."},
    {"item": 6, "question": "Sino ang unang pangulo ng Pilipinas?", "answer": "Si Emilio Aguinaldo ang unang pangulo ng Pilipinas."},
    {"item": 7, "question": "What is the name of the traditional Filipino house made of bamboo and nipa?", "answer": "The traditional Filipino house is called a bahay kubo."},
    {"item": 8, "question": "Ano ang pangunahing wika na ginagamit sa Pilipinas?", "answer": "Ang Tagalog ay ang pangunahing wika, na naging batayan ng Filipino, ang pambansang wika."},
    {"item": 9, "question": "What is the Ati-Atihan festival known for?", "answer": "The Ati-Atihan festival is known for its vibrant street dancing and celebration of the Sto. Niño in Kalibo, Aklan."},
    {"item": 10, "question": "Ano ang ‘kundiman’ sa konteksto ng musikang Pilipino?", "answer": "Ang kundiman ay isang tradisyunal na awitin ng pag-ibig na nagpapahayag ng damdamin at patriotismo."},
    {"item": 11, "question": "What is the traditional Filipino Christmas lantern called?", "answer": "The traditional Filipino Christmas lantern is called a parol."},
    {"item": 12, "question": "Sino ang kilalang pintor na lumikha ng ‘Spoliarium’?", "answer": "Si Juan Luna ang pintor na lumikha ng ‘Spoliarium’."},
    {"item": 13, "question": "What is the role of the ‘barrio’ in Filipino society?", "answer": "The barrio is a small community or village that serves as a basic social and administrative unit in rural Philippines."},
    {"item": 14, "question": "Ano ang ‘balut’ sa kulturang Pilipino?", "answer": "Ang balut ay isang fertilized duck egg na kinakain bilang street food sa Pilipinas."},
    {"item": 15, "question": "What is the significance of the EDSA Revolution?", "answer": "The EDSA Revolution of 1986 was a peaceful uprising that led to the ouster of Ferdinand Marcos and the restoration of democracy."},
    {"item": 16, "question": "Ano ang pangalan ng tradisyunal na damit ng kababaihan sa Pilipinas?", "answer": "Ang tradisyunal na damit ng kababaihan ay tinutukoy bilang ‘baro’t saya’."},
    {"item": 17, "question": "What is the traditional Filipino game ‘sipa’?", "answer": "Sipa is a traditional Filipino game where players kick a rattan ball to keep it in the air."},
    {"item": 18, "question": "Ano ang kahulugan ng ‘mano po’ sa tradisyong Pilipino?", "answer": "Ang ‘mano po’ ay isang tradisyunal na kilos ng paggalang kung saan hinawakan ang kamay ng nakatatanda at idinadampi sa noo."},
    {"item": 19, "question": "What is the name of the epic poem from the Ilocano people?", "answer": "The epic poem of the Ilocano people is called Biag ni Lam-ang."},
    {"item": 20, "question": "Ano ang ‘Pahiyas’ festival sa Quezon?", "answer": "Ang Pahiyas festival ay isang makulay na pagdiriwang sa Lucban, Quezon, kung saan pinalalamutian ang mga bahay ng kiping at ani bilang pasasalamat."},
    {"item": 21, "question": "What is the traditional Filipino dance that mimics the movements of birds?", "answer": "The Tinikling is a traditional Filipino dance that mimics the movements of birds hopping between bamboo poles."},
    {"item": 22, "question": "Ano ang ‘lechon’ sa konteksto ng pagkain sa Pilipinas?", "answer": "Ang lechon ay isang inihaw na buong baboy na madalas ihinahain sa mga pista at espesyal na okasyon."},
    {"item": 23, "question": "Who wrote the novel ‘Noli Me Tangere’?", "answer": "Jose Rizal wrote the novel ‘Noli Me Tangere’."},
    {"item": 24, "question": "Ano ang pangalan ng tradisyunal na instrumento na gawa sa kawayan?", "answer": "Ang kudyapi ay isang tradisyunal na instrumento na gawa sa kawayan at ginagamit sa musika ng mga katutubo."},
    {"item": 25, "question": "What is the significance of the ‘Flores de Mayo’ celebration?", "answer": "Flores de Mayo is a month-long celebration in May honoring the Virgin Mary with floral offerings and processions."},
    {"item": 26, "question": "Sino ang kilalang bayani na nanguna sa Katipunan?", "answer": "Si Andres Bonifacio ang nanguna sa Katipunan."},
    {"item": 27, "question": "What is the traditional Filipino rice cake called?", "answer": "The traditional Filipino rice cake is called bibingka."},
    {"item": 28, "question": "Ano ang ‘Panagbenga’ festival sa Baguio?", "answer": "Ang Panagbenga ay isang flower festival sa Baguio na nagpapakita ng mga makukulay na parada ng bulaklak."},
    {"item": 29, "question": "What is the meaning of ‘utang na loob’ in Filipino culture?", "answer": "Utang na loob refers to a debt of gratitude, a cultural value emphasizing reciprocity and obligation."},
    {"item": 30, "question": "Ano ang pangalan ng tradisyunal na sayaw ng mga Igorot?", "answer": "Ang tradisyunal na sayaw ng mga Igorot ay tinutukoy bilang ‘bangko’ o ‘canao’."},
    {"item": 31, "question": "What is the traditional Filipino dessert made from sticky rice and coconut milk?", "answer": "The traditional Filipino dessert is called suman."},
    {"item": 32, "question": "Ano ang ‘Moriones’ festival sa Marinduque?", "answer": "Ang Moriones festival ay isang pagdiriwang kung saan ang mga kalahok ay nagsusuot ng maskara bilang mga sundalong Romano bilang bahagi ng Semana Santa."},
    {"item": 33, "question": "Who is the Filipino heroine known as the ‘Joan of Arc of the Philippines’?", "answer": "Gabriela Silang is known as the ‘Joan of Arc of the Philippines’."},
    {"item": 34, "question": "Ano ang ‘harana’ sa tradisyong Pilipino?", "answer": "Ang harana ay ang tradisyon ng panliligaw sa pamamagitan ng pagkanta ng mga awiting pag-ibig sa labas ng bahay ng babae."},
    {"item": 35, "question": "What is the traditional Filipino martial art called?", "answer": "The traditional Filipino martial art is called Arnis or Eskrima."},
    {"item": 36, "question": "Ano ang pangunahing sangkap ng kare-kare?", "answer": "Ang pangunahing sangkap ng kare-kare ay mani, na ginagamit sa sarsa, kasabay ng karne at gulay."},
    {"item": 37, "question": "What is the significance of the Malolos Constitution?", "answer": "The Malolos Constitution was the first republican constitution in Asia, established in 1899 for the First Philippine Republic."},
    {"item": 38, "question": "Sino ang kilalang manunulat ng ‘Florante at Laura’?", "answer": "Si Francisco Balagtas ang manunulat ng ‘Florante at Laura’."},
    {"item": 39, "question": "What is the traditional Filipino game involving a spinning top?", "answer": "The traditional Filipino game involving a spinning top is called trompo."},
    {"item": 40, "question": "Ano ang ‘Simbang Gabi’ sa tradisyong Pilipino?", "answer": "Ang Simbang Gabi ay isang serye ng siyam na misa bago ang Pasko, na isinasagawa sa madaling araw bilang paghahanda sa Kapaskuhan."},
    {"item": 41, "question": "What is the Kadayawan festival in Davao known for?", "answer": "The Kadayawan festival is a celebration of Davao’s indigenous culture and bountiful harvest, featuring street dancing and floral floats."},
    {"item": 42, "question": "Sino ang kilalang eskultor na gumawa ng Oblation statue?", "answer": "Si Guillermo Tolentino ang eskultor na gumawa ng Oblation statue."},
    {"item": 43, "question": "What is the traditional Filipino practice of ‘pasalubong’?", "answer": "Pasalubong is the tradition of bringing gifts or souvenirs to family and friends after a trip."},
    {"item": 44, "question": "Ano ang pangalan ng tradisyunal na sayaw na gumagamit ng pandan leaves?", "answer": "Ang tradisyunal na sayaw na gumagamit ng pandan leaves ay tinutukoy bilang Pandanggo sa Ilaw."},
    {"item": 45, "question": "What is the significance of the ‘Santacruzan’ procession?", "answer": "The Santacruzan is a religious procession held during Flores de Mayo, reenacting the search for the Holy Cross."},
    {"item": 46, "question": "Ano ang ‘halo-halo’ sa konteksto ng pagkain?", "answer": "Ang halo-halo ay isang sikat na dessert na pinaghalong yelo, gatas, prutas, at iba pang sangkap."},
    {"item": 47, "question": "Who was the first Filipino to win a gold medal in the Olympics?", "answer": "Hidilyn Diaz was the first Filipino to win a gold medal in the Olympics, in weightlifting at the 2020 Tokyo Games."},
    {"item": 48, "question": "Ano ang kahulugan ng ‘hiya’ sa kulturang Pilipino?", "answer": "Ang hiya ay tumutukoy sa pakiramdam ng kahihiyan o pagpapahalaga sa dangal at reputasyon sa lipunan."},
    {"item": 49, "question": "What is the traditional Filipino weaving technique used in T’nalak cloth?", "answer": "The traditional weaving technique for T’nalak cloth is called dream weaving, practiced by the T’boli people."},
    {"item": 50, "question": "Ano ang ‘MassKara’ festival sa Bacolod?", "answer": "Ang MassKara festival ay isang makulay na pagdiriwang sa Bacolod na nagpapakita ng mga maskara at sayaw bilang simbolo ng kaligayahan."},
    {"item": 51, "question": "What is the significance of the Banaue Rice Terraces?", "answer": "The Banaue Rice Terraces, built by the Ifugao people, are a UNESCO World Heritage Site symbolizing agricultural ingenuity."},
    {"item": 52, "question": "Sino ang kilalang kompositor ng ‘Sa Ugoy ng Duyan’?", "answer": "Si Lucio San Pedro ang kompositor ng ‘Sa Ugoy ng Duyan’."},
    {"item": 53, "question": "What is the traditional Filipino dish ‘sisig’ made of?", "answer": "Sisig is a dish made from chopped pig’s head and liver, seasoned with calamansi and chili."},
    {"item": 54, "question": "Ano ang ‘Magellan’s Cross’ sa Cebu?", "answer": "Ang Magellan’s Cross ay isang makasaysayang krus na itinanim ni Ferdinand Magellan sa Cebu bilang simbolo ng Kristiyanismo."},
    {"item": 55, "question": "What is the traditional Filipino game ‘piko’?", "answer": "Piko is a traditional Filipino hopscotch game played on a drawn grid using a marker like a stone."},
    {"item": 56, "question": "Ano ang ‘Dinagyang’ festival sa Iloilo?", "answer": "Ang Dinagyang festival ay isang relihiyosong pagdiriwang sa Iloilo na nagbibigay-pugay sa Sto. Niño sa pamamagitan ng sayaw."},
    {"item": 57, "question": "Who is the Filipino poet known as ‘Huseng Sisiw’?", "answer": "Jose Corazon de Jesus is known as ‘Huseng Sisiw’."},
    {"item": 58, "question": "Ano ang pangalan ng tradisyunal na awitin ng mga Tagalog na ginagamit sa libing?", "answer": "Ang tradisyunal na awitin sa libing ay tinutukoy bilang ‘dung-aw’."},
    {"item": 59, "question": "What is the significance of the ‘Katipunan’ in Philippine history?", "answer": "The Katipunan was a revolutionary organization founded by Andres Bonifacio to fight for independence from Spanish rule."},
    {"item": 60, "question": "Ano ang ‘tuba’ sa konteksto ng inumin sa Pilipinas?", "answer": "Ang tuba ay isang tradisyunal na inuming alkohol mula sa katas ng niyog."},
    {"item": 61, "question": "What is the traditional Filipino dance ‘Cariñosa’ known for?", "answer": "The Cariñosa is a romantic Filipino dance characterized by the use of fans and handkerchiefs."},
    {"item": 62, "question": "Sino ang kilalang bayani na tinuturing na ‘Brains of the Katipunan’?", "answer": "Si Emilio Jacinto ang tinuturing na ‘Brains of the Katipunan’."},
    {"item": 63, "question": "What is the traditional Filipino snack ‘kakanin’?", "answer": "Kakanin refers to a variety of Filipino snacks made from glutinous rice, such as puto and biko."},
    {"item": 64, "question": "Ano ang ‘Higantes’ festival sa Angono?", "answer": "Ang Higantes festival ay isang pagdiriwang sa Angono, Rizal, na nagtatampok ng malalaking papier-mâché na pigura."},
    {"item": 65, "question": "What is the significance of the ‘Lapu-Lapu’ monument in Cebu?", "answer": "The Lapu-Lapu monument commemorates the chieftain who defeated Ferdinand Magellan in the Battle of Mactan."},
    {"item": 66, "question": "Ano ang pangalan ng tradisyunal na kasalan sa Pilipinas?", "answer": "Ang tradisyunal na kasalan sa Pilipinas ay tinutukoy bilang ‘kasalan sa simbahan’ o ‘pamamanhikan’."},
    {"item": 67, "question": "What is the traditional Filipino instrument ‘bandurria’ used for?", "answer": "The bandurria is a stringed instrument used in rondalla ensembles to play traditional Filipino music."},
    {"item": 68, "question": "Ano ang ‘Obando’ festival sa Bulacan?", "answer": "Ang Obando festival ay isang pagdiriwang ng pagkamayabong, na may sayaw bilang pagbibigay-pugay kina Santa Clara, San Pascual, at San Isidro."},
    {"item": 69, "question": "What is the traditional Filipino dish ‘tinola’ made of?", "answer": "Tinola is a chicken soup dish made with green papaya, chili leaves, and ginger."},
    {"item": 70, "question": "Sino ang kilalang manunulat ng ‘El Filibusterismo’?", "answer": "Si Jose Rizal ang manunulat ng ‘El Filibusterismo’."},
    {"item": 71, "question": "What is the traditional Filipino practice of ‘alay’?", "answer": "Alay refers to offerings made to deities or spirits in Filipino folk religion."},
    {"item": 72, "question": "Ano ang ‘Kaamulan’ festival sa Bukidnon?", "answer": "Ang Kaamulan festival ay isang pagdiriwang ng kultura ng mga katutubong grupo sa Bukidnon."},
    {"item": 73, "question": "What is the significance of the ‘Rizal Park’ in Manila?", "answer": "Rizal Park, also known as Luneta, is a historic park dedicated to Jose Rizal, where he was executed."},
    {"item": 74, "question": "Ano ang ‘tsinelas’ sa konteksto ng tradisyunal na kasuotan?", "answer": "Ang tsinelas ay tumutukoy sa tradisyunal na sandal na madalas ginagamit sa pang-araw-araw na buhay sa Pilipinas."},
    {"item": 75, "question": "What is the traditional Filipino game ‘luksong tinik’?", "answer": "Luksong tinik is a traditional Filipino game where players jump over obstacles made of hands and feet."},
    {"item": 76, "question": "Ano ang pangalan ng tradisyunal na awitin ng mga Ilonggo?", "answer": "Ang tradisyunal na awitin ng mga Ilonggo ay tinutukoy bilang ‘dandansoy’."},
    {"item": 77, "question": "What is the significance of the ‘T’nalak’ festival in South Cotabato?", "answer": "The T’nalak festival celebrates the T’boli people’s weaving tradition, particularly the T’nalak cloth."},
    {"item": 78, "question": "Sino ang kilalang bayani na tinaguriang ‘Heneral Luna’?", "answer": "Si Antonio Luna ang tinaguriang ‘Heneral Luna’."},
    {"item": 79, "question": "What is the traditional Filipino dish ‘pancit’?", "answer": "Pancit is a noodle dish with various regional styles, often served at celebrations."},
    {"item": 80, "question": "Ano ang ‘Sandugo’ festival sa Bohol?", "answer": "Ang Sandugo festival ay nagdiriwang ng kasunduan sa dugo sa pagitan nina Miguel Lopez de Legazpi at Datu Sikatuna."},
    {"item": 81, "question": "What is the traditional Filipino practice of ‘pamanhikan’?", "answer": "Pamanhikan is the tradition where the groom’s family formally asks for the bride’s hand in marriage."},
    {"item": 82, "question": "Ano ang ‘Ifugao’ hut sa konteksto ng arkitektura?", "answer": "Ang Ifugao hut ay isang tradisyunal na bahay ng mga Ifugao na may mataas na bubong at gawa sa kahoy at dayami."},
    {"item": 83, "question": "What is the significance of the ‘Intramuros’ in Manila?", "answer": "Intramuros is the historic walled city in Manila, built during Spanish colonial times."},
    {"item": 84, "question": "Ano ang ‘kundiman’ festival sa Balayan, Batangas?", "answer": "Ang kundiman festival ay isang pagdiriwang ng tradisyunal na musikang Pilipino, partikular ang kundiman."},
    {"item": 85, "question": "What is the traditional Filipino dessert ‘leche flan’?", "answer": "Leche flan is a creamy custard dessert made from eggs, milk, and caramel."},
    {"item": 86, "question": "Sino ang kilalang bayani na tinaguriang ‘Boy General’?", "answer": "Si Gregorio del Pilar ang tinaguriang ‘Boy General’."},
    {"item": 87, "question": "What is the traditional Filipino game ‘sungka’?", "answer": "Sungka is a traditional Filipino board game played with shells or stones in a wooden board."},
    {"item": 88, "question": "Ano ang ‘Lanzones’ festival sa Camiguin?", "answer": "Ang Lanzones festival ay isang pagdiriwang ng ani ng lanzones sa Camiguin."},
    {"item": 89, "question": "What is the significance of the ‘Philippine Eagle’ in Filipino culture?", "answer": "The Philippine Eagle is a national symbol of strength and conservation efforts."},
    {"item": 90, "question": "Ano ang ‘balete’ tree sa folklor ng Pilipino?", "answer": "Ang balete tree ay itinuturing na sagrado o tahanan ng mga espiritu sa folklor ng Pilipino."},
    {"item": 91, "question": "What is the traditional Filipino dance ‘Pandanggo sa Ilaw’ known for?", "answer": "Pandanggo sa Ilaw is a dance that involves balancing oil lamps on the head and hands."},
    {"item": 92, "question": "Sino ang kilalang kompositor ng ‘Kay Ganda ng Ating Musika’?", "answer": "Si Ryan Cayabyab ang kompositor ng ‘Kay Ganda ng Ating Musika’."},
    {"item": 93, "question": "What is the traditional Filipino dish ‘bulalo’?", "answer": "Bulalo is a beef shank soup with bone marrow, often cooked with vegetables."},
    {"item": 94, "question": "Ano ang ‘Cutud Lenten Rites’ sa Pampanga?", "answer": "Ang Cutud Lenten Rites ay isang tradisyon sa Pampanga kung saan ginaganap ang reenactment ng pagpapako sa krus tuwing Semana Santa."},
    {"item": 95, "question": "What is the significance of the ‘Chocolate Hills’ in Bohol?", "answer": "The Chocolate Hills are a geological formation and tourist attraction in Bohol, named for their brown appearance during the dry season."},
    {"item": 96, "question": "Ano ang ‘salakot’ sa konteksto ng tradisyunal na kasuotan?", "answer": "Ang salakot ay isang tradisyunal na sumbrero na gawa sa kawayan o rattan, ginagamit bilang proteksyon sa araw."},
    {"item": 97, "question": "What is the traditional Filipino practice of ‘anting-anting’?", "answer": "Anting-anting refers to amulets or charms believed to provide protection or power in Filipino folk beliefs."},
    {"item": 98, "question": "Ano ang ‘Sublian’ festival sa Batangas?", "answer": "Ang Sublian festival ay isang pagdiriwang sa Batangas na nagbibigay-pugay sa Sto. Niño sa pamamagitan ng sayaw at awitin."},
    {"item": 99, "question": "What is the traditional Filipino dish ‘kinilaw’?", "answer": "Kinilaw is a dish of raw fish marinated in vinegar or citrus, similar to ceviche."},
    {"item": 100, "question": "Ano ang kahulugan ng ‘kapwa’ sa kulturang Pilipino?", "answer": "Ang ‘kapwa’ ay tumutukoy sa pakikipagkapwa-tao, ang pagtrato sa iba bilang kapantay at bahagi ng sarili."},
        {"item": 101, "question": "Sino ang tinuturing na ‘Sublime Paralytic’ sa kasaysayan ng Pilipinas?", "answer": "Si Apolinario Mabini ang tinuturing na ‘Sublime Paralytic’."},
    {"item": 102, "question": "What is the traditional Filipino dish ‘menudo’ made of?", "answer": "Menudo is a pork stew made with liver, tomatoes, potatoes, and bell peppers."},
    {"item": 103, "question": "Ano ang ‘Pintados’ festival sa Tacloban?", "answer": "Ang Pintados festival ay isang pagdiriwang sa Tacloban na nagpapakita ng tradisyunal na tattoo ng mga Waray bilang simbolo ng kultura."},
    {"item": 104, "question": "What is the significance of the ‘Cry of Pugad Lawin’?", "answer": "The Cry of Pugad Lawin in 1896 marked the start of the Philippine Revolution against Spanish rule, led by Andres Bonifacio."},
    {"item": 105, "question": "Ano ang ‘sari-sari’ store sa konteksto ng kulturang Pilipino?", "answer": "Ang sari-sari store ay isang maliit na tindahan na nagbebenta ng iba’t ibang pang-araw-araw na produkto sa komunidad."},
    {"item": 106, "question": "What is the traditional Filipino epic ‘Ibong Adarna’ about?", "answer": "Ibong Adarna is a mythical epic about a magical bird whose song can heal or harm, and the adventures of three princes."},
    {"item": 107, "question": "Sino ang kilalang bayani na tinaguriang ‘Tandang Sora’?", "answer": "Si Melchora Aquino ang tinaguriang ‘Tandang Sora’."},
    {"item": 108, "question": "What is the traditional Filipino dish ‘dinuguan’?", "answer": "Dinuguan is a savory stew made from pork blood and meat, often spiced with vinegar and chili."},
    {"item": 109, "question": "Ano ang ‘Ibalong’ festival sa Legazpi?", "answer": "Ang Ibalong festival ay isang pagdiriwang sa Legazpi na nagbibigay-pugay sa epikong Bicolano tungkol sa mga bayani at mitolohiya."},
    {"item": 110, "question": "What is the traditional Filipino practice of ‘pagpag’?", "answer": "Pagpag is a superstition where one avoids going straight home after a wake to shake off bad spirits."},
    {"item": 111, "question": "Ano ang pangalan ng tradisyunal na sayaw ng mga Maranao?", "answer": "Ang tradisyunal na sayaw ng mga Maranao ay tinutukoy bilang ‘Singkil’."},
    {"item": 112, "question": "What is the significance of Fort Santiago in Manila?", "answer": "Fort Santiago is a historic fortress in Intramuros where Jose Rizal was imprisoned before his execution."},
    {"item": 113, "question": "Sino ang kilalang manunulat ng ‘Ang Matanda at ang Dagat’ sa Pilipinas?", "answer": "Si Edith Tiempo ang kilalang manunulat na Pilipino na nauugnay sa panitikan."},
    {"item": 114, "question": "What is the traditional Filipino game ‘palo sebo’?", "answer": "Palo sebo is a traditional Filipino game where players climb a greased bamboo pole to reach a prize at the top."},
    {"item": 115, "question": "Ano ang ‘Hermosa’ festival sa Zamboanga?", "answer": "Ang Hermosa festival ay isang pagdiriwang sa Zamboanga na nagbibigay-pugay sa Nuestra Señora del Pilar."},
    {"item": 116, "question": "What is the traditional Filipino dish ‘pinakbet’?", "answer": "Pinakbet is a vegetable stew from Ilocos, cooked with shrimp paste and mixed with local vegetables."},
    {"item": 117, "question": "Ano ang kahulugan ng ‘po’ at ‘opo’ sa wikang Tagalog?", "answer": "Ang ‘po’ at ‘opo’ ay mga salitang nagpapakita ng paggalang sa mga nakatatanda sa wikang Tagalog."},
    {"item": 118, "question": "What is the significance of the Vigan heritage site?", "answer": "Vigan is a UNESCO World Heritage Site known for its well-preserved Spanish colonial architecture."},
    {"item": 119, "question": "Sino ang unang babaeng pangulo ng Pilipinas?", "answer": "Si Corazon Aquino ang unang babaeng pangulo ng Pilipinas."},
    {"item": 120, "question": "Ano ang ‘banig’ sa konteksto ng tradisyunal na sining?", "answer": "Ang banig ay isang tradisyunal na hinabing tikar na gawa sa dahon ng pandan o buri."},
    {"item": 121, "question": "What is the traditional Filipino game ‘patintero’?", "answer": "Patintero is a traditional Filipino street game where players try to cross a grid without being tagged."},
    {"item": 122, "question": "Ano ang ‘Kadayawan’ festival sa Davao?", "answer": "Ang Kadayawan festival ay isang pagdiriwang ng kultura ng mga katutubo at ani sa Davao."},
    {"item": 123, "question": "What is the significance of the ‘Mayon Volcano’ in Filipino culture?", "answer": "Mayon Volcano in Albay is a cultural and natural landmark known for its perfect cone shape."},
    {"item": 124, "question": "Sino ang kilalang pintor ng ‘Planting Rice’?", "answer": "Si Fernando Amorsolo ang pintor ng ‘Planting Rice’."},
    {"item": 125, "question": "What is the traditional Filipino dish ‘afritada’?", "answer": "Afritada is a tomato-based stew with chicken or pork, potatoes, and bell peppers."},
    {"item": 126, "question": "Ano ang ‘Bamboo Organ’ sa Las Piñas?", "answer": "Ang Bamboo Organ ay isang natatanging organo sa simbahan ng Las Piñas na gawa sa kawayan."},
    {"item": 127, "question": "What is the traditional Filipino practice of ‘pamana’?", "answer": "Pamana refers to the tradition of passing down heirlooms or inheritance to the next generation."},
    {"item": 128, "question": "Ano ang ‘Pintaflores’ festival sa Bogo, Cebu?", "answer": "Ang Pintaflores festival ay isang pagdiriwang sa Bogo, Cebu, na nagpapakita ng mga tattoo-inspired na sayaw."},
    {"item": 129, "question": "What is the significance of the ‘Basi Revolt’ in Ilocos?", "answer": "The Basi Revolt of 1807 was an uprising in Ilocos against Spanish restrictions on basi wine production."},
    {"item": 130, "question": "Ano ang ‘rondalla’ sa konteksto ng musikang Pilipino?", "answer": "Ang rondalla ay isang ensemble ng mga instrumentong may kuwerdas tulad ng bandurria at gitara."},
    {"item": 131, "question": "What is the traditional Filipino dish ‘caldereta’?", "answer": "Caldereta is a spicy tomato-based stew, typically made with goat meat or beef."},
    {"item": 132, "question": "Sino ang kilalang bayani na nanguna sa ‘Battle of Tirad Pass’?", "answer": "Si Gregorio del Pilar ang nanguna sa Battle of Tirad Pass."},
    {"item": 133, "question": "What is the traditional Filipino practice of ‘barkada’?", "answer": "Barkada refers to a close group of friends who share strong social bonds in Filipino culture."},
    {"item": 134, "question": "Ano ang ‘T’boli’ tribe sa konteksto ng kulturang Pilipino?", "answer": "Ang T’boli ay isang katutubong grupo sa South Cotabato na kilala sa kanilang sining sa paghahabi ng T’nalak."},
    {"item": 135, "question": "What is the significance of the ‘San Juanico Bridge’?", "answer": "The San Juanico Bridge connects Samar and Leyte, symbolizing regional unity and engineering."},
    {"item": 136, "question": "Ano ang ‘buko pie’ sa konteksto ng pagkain?", "answer": "Ang buko pie ay isang tradisyunal na dessert na gawa sa batang niyog, gatas, at asukal."},
    {"item": 137, "question": "What is the traditional Filipino game ‘tumbang preso’?", "answer": "Tumbang preso is a game where players try to knock over a can with a slipper while avoiding being tagged."},
    {"item": 138, "question": "Sino ang kilalang manunulat ng ‘Banaag at Sikat’?", "answer": "Si Lope K. Santos ang manunulat ng ‘Banaag at Sikat’."},
    {"item": 139, "question": "What is the significance of the ‘Barasoain Church’ in Malolos?", "answer": "Barasoain Church is known as the ‘Cradle of Democracy’ where the Malolos Constitution was drafted."},
    {"item": 140, "question": "Ano ang ‘Pasyon’ sa tradisyong Pilipino?", "answer": "Ang Pasyon ay isang tradisyunal na pag-awit o pagbasa ng salaysay ng buhay ni Hesukristo tuwing Semana Santa."},
    {"item": 141, "question": "What is the traditional Filipino dish ‘laing’?", "answer": "Laing is a Bicolano dish made from taro leaves cooked in coconut milk with chili."},
    {"item": 142, "question": "Ano ang ‘Kutang Bato’ sa Palawan?", "answer": "Ang Kutang Bato ay isang makasaysayang kuta sa Puerto Princesa, Palawan, na itinayo noong panahon ng Espanyol."},
    {"item": 143, "question": "What is the traditional Filipino practice of ‘hilot’?", "answer": "Hilot is a traditional Filipino healing massage used to treat ailments and promote wellness."},
    {"item": 144, "question": "Sino ang kilalang kompositor ng ‘Pandanggo sa Ilaw’?", "answer": "Si Antonino Buenaventura ang kilalang kompositor na nauugnay sa ‘Pandanggo sa Ilaw’."},
    {"item": 145, "question": "What is the significance of the ‘Bataan Death March’?", "answer": "The Bataan Death March of 1942 was a forced march of Filipino and American prisoners by Japanese forces during WWII."},
    {"item": 146, "question": "Ano ang ‘piña’ fabric sa konteksto ng tradisyunal na tela?", "answer": "Ang piña fabric ay isang tradisyunal na tela na gawa sa hibla ng dahon ng pinya, ginagamit sa Barong Tagalog."},
    {"item": 147, "question": "What is the traditional Filipino game ‘agawan base’?", "answer": "Agawan base is a team-based game where players try to capture the opponent’s base while protecting their own."},
    {"item": 148, "question": "Ano ang ‘Buwan ng Wika’ sa Pilipinas?", "answer": "Ang Buwan ng Wika ay isang pagdiriwang tuwing Agosto upang itaguyod ang wikang Filipino at kultura."},
    {"item": 149, "question": "What is the significance of the ‘Taal Volcano’ in Batangas?", "answer": "Taal Volcano is a cultural and natural landmark known for its scenic crater lake and active status."},
    {"item": 150, "question": "Sino ang kilalang bayani na tinaguriang ‘Hero of Tondo’?", "answer": "Si Andres Bonifacio ang tinaguriang ‘Hero of Tondo’."},
    {"item": 151, "question": "What is the traditional Filipino dish ‘bistek Tagalog’?", "answer": "Bistek Tagalog is a dish of beef slices marinated in soy sauce and calamansi, cooked with onions."},
    {"item": 152, "question": "Ano ang ‘Araw ng Kalayaan’ sa Pilipinas?", "answer": "Ang Araw ng Kalayaan ay ipinagdiriwang tuwing Hunyo 12 bilang paggunita sa kalayaan mula sa Espanya noong 1898."},
    {"item": 153, "question": "What is the traditional Filipino practice of ‘araw-araw’?", "answer": "Araw-araw refers to the daily communal or family prayers, often in a religious context."},
    {"item": 154, "question": "Ano ang ‘Mangyan’ tribe sa konteksto ng kulturang Pilipino?", "answer": "Ang Mangyan ay isang katutubong grupo sa Mindoro na kilala sa kanilang natatanging wika at sining."},
    {"item": 155, "question": "What is the significance of the ‘San Agustin Church’ in Manila?", "answer": "San Agustin Church is a UNESCO World Heritage Site and the oldest stone church in the Philippines."},
    {"item": 156, "question": "Ano ang ‘bibingkahan’ sa konteksto ng pagkain?", "answer": "Ang bibingkahan ay isang tradisyunal na lugar o stall kung saan inihanda at ibinebenta ang bibingka."},
    {"item": 157, "question": "What is the traditional Filipino game ‘kadang-kadang’?", "answer": "Kadang-kadang is a game where players race on stilts made of bamboo."},
    {"item": 158, "question": "Sino ang kilalang pintor ng ‘The Parisian Life’?", "answer": "Si Juan Luna ang pintor ng ‘The Parisian Life’."},
    {"item": 159, "question": "What is the significance of the ‘Roxas Boulevard’ in Manila?", "answer": "Roxas Boulevard is a historic waterfront promenade in Manila, known for its cultural and scenic value."},
    {"item": 160, "question": "Ano ang ‘Hinilawod’ sa konteksto ng panitikan ng Pilipino?", "answer": "Ang Hinilawod ay isang epikong Visayan tungkol sa mga pakikipagsapalaran ng bayaning si Labaw Donggon."},
    {"item": 161, "question": "What is the traditional Filipino dish ‘bagoong’?", "answer": "Bagoong is a fermented fish or shrimp paste used as a condiment or ingredient in Filipino cuisine."},
    {"item": 162, "question": "Ano ang ‘Regatta de Zamboanga’?", "answer": "Ang Regatta de Zamboanga ay isang karera ng mga makukulay na bangka o vinta sa Zamboanga."},
    {"item": 163, "question": "What is the traditional Filipino practice of ‘panunuluyan’?", "answer": "Panunuluyan is a Christmas tradition reenacting Mary and Joseph’s search for lodging in Bethlehem."},
    {"item": 164, "question": "Sino ang kilalang bayani na tinaguriang ‘Hukbalahap’ leader?", "answer": "Si Luis Taruc ang kilalang lider ng Hukbalahap."},
    {"item": 165, "question": "What is the significance of the ‘Paoay Church’ in Ilocos Norte?", "answer": "Paoay Church is a UNESCO World Heritage Site known for its earthquake-resistant baroque architecture."},
    {"item": 166, "question": "Ano ang ‘tinikling’ sa konteksto ng sayaw?", "answer": "Ang tinikling ay isang tradisyunal na sayaw na gumagamit ng mga kawayan at ginagaya ang galaw ng ibon."},
    {"item": 167, "question": "What is the traditional Filipino dish ‘lugaw’?", "answer": "Lugaw is a rice porridge often served with chicken, egg, or tripe."},
    {"item": 168, "question": "Ano ang ‘Bagobo’ tribe sa konteksto ng kulturang Pilipino?", "answer": "Ang Bagobo ay isang katutubong grupo sa Davao na kilala sa kanilang makulay na damit at sining."},
    {"item": 169, "question": "What is the significance of the ‘Corregidor Island’?", "answer": "Corregidor Island is a historic site known for its role in WWII as a military stronghold."},
    {"item": 170, "question": "Sino ang kilalang manunulat ng ‘Doctrina Christiana’?", "answer": "Ang Doctrina Christiana ay isinulat ng mga prayleng Espanyol, ang unang aklat na naiimprenta sa Pilipinas."},
    {"item": 171, "question": "What is the traditional Filipino game ‘sack race’?", "answer": "The sack race, or sako race, is a traditional game where players race while inside a sack."},
    {"item": 172, "question": "Ano ang ‘Ati’ tribe sa konteksto ng kulturang Pilipino?", "answer": "Ang Ati ay isang katutubong grupo sa Panay, na kilala sa Ati-Atihan festival."},
    {"item": 173, "question": "What is the significance of the ‘Miagao Church’ in Iloilo?", "answer": "Miagao Church is a UNESCO World Heritage Site known for its ornate baroque facade."},
    {"item": 174, "question": "Ano ang ‘suman sa ibos’ sa konteksto ng pagkain?", "answer": "Ang suman sa ibos ay isang kakanin na gawa sa malagkit na bigas at niyog, balot sa dahon ng niyog."},
    {"item": 175, "question": "What is the traditional Filipino practice of ‘komedya’?", "answer": "Komedya is a traditional Filipino theatrical play depicting historical or religious stories."},
    {"item": 176, "question": "Sino ang kilalang kompositor ng ‘Mutya ng Pasig’?", "answer": "Si Nicanor Abelardo ang kompositor ng ‘Mutya ng Pasig’."},
    {"item": 177, "question": "What is the significance of the ‘Dambana ng Kagitingan’ in Bataan?", "answer": "The Dambana ng Kagitingan is a memorial shrine in Bataan honoring WWII heroes."},
    {"item": 178, "question": "Ano ang ‘salu-salo’ sa konteksto ng kulturang Pilipino?", "answer": "Ang salu-salo ay isang tradisyunal na pagtitipon o piging kasama ang pamilya o kaibigan."},
    {"item": 179, "question": "What is the traditional Filipino dish ‘kwek-kwek’?", "answer": "Kwek-kwek is a street food made of battered and fried quail eggs."},
    {"item": 180, "question": "Ano ang ‘Kawayan’ festival sa Abra?", "answer": "Ang Kawayan festival ay isang pagdiriwang sa Abra na nagbibigay-pugay sa kawayan bilang mahalagang materyal."},
    {"item": 181, "question": "What is the significance of the ‘Aguinaldo Shrine’ in Kawit?", "answer": "The Aguinaldo Shrine is where Emilio Aguinaldo declared Philippine independence in 1898."},
    {"item": 182, "question": "Ano ang ‘balagtasan’ sa konteksto ng panitikan?", "answer": "Ang balagtasan ay isang tradisyunal na debate sa tula na pinangalanan kay Francisco Balagtas."},
    {"item": 183, "question": "What is the traditional Filipino game ‘bahay-bahayan’?", "answer": "Bahay-bahayan is a role-playing game where children mimic family life and household roles."},
    {"item": 184, "question": "Sino ang kilalang bayani na tinaguriang ‘Hero of Cavite’?", "answer": "Si Emilio Aguinaldo ang tinaguriang ‘Hero of Cavite’."},
    {"item": 185, "question": "What is the traditional Filipino dish ‘isaw’?", "answer": "Isaw is a street food made from grilled pork or chicken intestines."},
    {"item": 186, "question": "Ano ang ‘Bolinao’ festival sa Pangasinan?", "answer": "Ang Bolinao festival ay isang pagdiriwang ng kultura at kasaysayan ng Bolinao, Pangasinan."},
    {"item": 187, "question": "What is the significance of the ‘People Power Monument’?", "answer": "The People Power Monument commemorates the 1986 EDSA Revolution in Quezon City."},
    {"item": 188, "question": "Ano ang ‘kundiman’ sa konteksto ng tradisyunal na musika?", "answer": "Ang kundiman ay isang genre ng musika na nagpapahayag ng pag-ibig at nasyonalismo."},
    {"item": 189, "question": "What is the traditional Filipino practice of ‘tabo’?", "answer": "Tabo is a traditional water dipper used for personal hygiene and cleaning in Filipino households."},
    {"item": 190, "question": "Sino ang kilalang pintor ng ‘Fruit Gatherer’?", "answer": "Si Fernando Amorsolo ang pintor ng ‘Fruit Gatherer’."},
    {"item": 191, "question": "What is the traditional Filipino dish ‘ginataang bilo-bilo’?", "answer": "Ginataang bilo-bilo is a dessert made of glutinous rice balls in coconut milk with fruits."},
    {"item": 192, "question": "Ano ang ‘Sagada’ sa konteksto ng kulturang Pilipino?", "answer": "Ang Sagada ay isang bayan sa Mountain Province na kilala sa hanging coffins at ecotourism."},
    {"item": 193, "question": "What is the significance of the ‘Battle of Mactan’?", "answer": "The Battle of Mactan in 1521 was where Lapu-Lapu defeated Ferdinand Magellan, marking early Filipino resistance."},
    {"item": 194, "question": "Ano ang ‘santo’ sa konteksto ng tradisyunal na sining?", "answer": "Ang santo ay isang inukit na imahe ng mga banal na ginagamit sa relihiyosong debosyon."},
    {"item": 195, "question": "What is the traditional Filipino game ‘taguan’?", "answer": "Taguan is the Filipino version of hide-and-seek, played by children."},
    {"item": 196, "question": "Sino ang kilalang manunulat ng ‘Ang Huling Timawa’?", "answer": "Si Jose Garcia Villa ang kilalang manunulat na nauugnay sa panitikan."},
    {"item": 197, "question": "What is the significance of the ‘Mount Apo’ in Davao?", "answer": "Mount Apo is the highest peak in the Philippines and a sacred site for indigenous groups."},
    {"item": 198, "question": "Ano ang ‘tawsug’ tribe sa konteksto ng kulturang Pilipino?", "answer": "Ang Tausug ay isang katutubong grupo sa Sulu na kilala sa kanilang sining at maritime culture."},
    {"item": 199, "question": "What is the traditional Filipino dish ‘champorado’?", "answer": "Champorado is a chocolate rice porridge often paired with dried fish."},
    {"item": 200, "question": "Ano ang ‘Panag-apoy’ festival sa Sagada?", "answer": "Ang Panag-apoy festival ay isang tradisyon sa Sagada kung saan sinisindihan ang mga pine wood bilang paggunita sa mga yumaong mahal sa buhay."}

]

# Save to JSON file
output_path = "evaluation.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(eval_data, f, ensure_ascii=False, indent=2)
print(f"[INFO] Saved evaluation dataset to {output_path}")
# Out:
# [INFO] Saved evaluation dataset to evaluation.json
